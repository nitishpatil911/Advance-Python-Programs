# %%
L=[1,2,3]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-a3553cd136be> in <cell line: 2>()
#       1 L=[1,2,3]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s="SODS"
s.append('A')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-c153f010918e> in <cell line: 2>()
#       1 s="SODS"
# ----> 2 s.append('A')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# Syntax to create an object name
# objectname=syntaxname()

# %%
L=[4,5,6]
L
# Out:
# [4, 5, 6]

# %%
L=list()
L
# Out:
# []

# %%
print(type(L))
# Out:
# <class 'list'>

# %%
class ATM:
  def __init__(self):
    self.pin=''
    self.balance=0
    print("Execution done")

# %%
sbi=ATM()
# Out:
# Execution done

# %%
print(type(sbi))
# Out:
# <class '__main__.ATM'>
