# %%
x=input("Enter the number:")
print(f"Multiplacation of table {x} is: ")
for i in range(1,11):
    print(f"{int(x)} X {i}={int(x)*i}")

print(" End of Program")
# Out:
# Enter the number:7
# Multiplacation of table 7 is:
# 7 X 1=7
# 7 X 2=14
# 7 X 3=21
# 7 X 4=28
# 7 X 5=35
# 7 X 6=42
# 7 X 7=49
# 7 X 8=56
# 7 X 9=63
# 7 X 10=70
#  End of Program

# %%
x=input("Enter the number:")
print(f"Multiplacation of table {x} is: ")
try:
   for i in range(1,11):
     print(f"{int(x)} X {i}={int(x)*i}")

except Exception as e:
    print("Invalid input")

print(" End of Program")
# Out:
# Enter the number:hello
# Multiplacation of table hello is:
# Invalid input
#  End of Program
