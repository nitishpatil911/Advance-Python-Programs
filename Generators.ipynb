# %%
# Generator Function in Python
# A generator function in Python is defined like a normal function,but whenever it needs to generate a value,
# it does so with the yield keyword rather than return. If the body of a def contains yield,
# the function automatically becomes a Python generator function.

# %%
def square(n):
  for i in range(n):
     return i**2

# %%
square(3)
# Out:
# 0

# %%
def square(n):
  for i in range(n):
     yield i**2

# %%
square(5)
# Out:
# <generator object square at 0x7d29ca51fe00>

# %%
for i in square(6):
     print(i)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25

# %%
def square(n):
  for i in range(n):
     return i**2

# %%
for i in square(3):
     print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-2990b799f79f> in <cell line: 0>()
# ----> 1 for i in square(3):
#       2      print(i)
#
# TypeError: 'int' object is not iterable
